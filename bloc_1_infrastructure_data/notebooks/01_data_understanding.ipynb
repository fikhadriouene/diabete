# %%
import pandas as pd
print("imports successfull")
# Out:
# imports successfull

# %%
df_raw = pd.read_sas("/bloc_1_infrastructure_data/data/LLCP2021.XPT")
print("dataset loaded successfully")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_raw = pd.read_sas("/bloc_1_infrastructure_data/data/LLCP2021.XPT")
#       2 print("dataset loaded successfully")
#
# File c:\Users\Administrateur\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sas\sasreader.py:154, in read_sas(filepath_or_buffer, format, index, encoding, chunksize, iterator, compression)
#     151 if format.lower() == "xport":
#     152     from pandas.io.sas.sas_xport import XportReader
# --> 154     reader = XportReader(
#     155         filepath_or_buffer,
#     156         index=index,
#     157         encoding=encoding,
#     158         chunksize=chunksize,
#     159         compression=compression,
#     160     )
#     161 elif format.lower() == "sas7bdat":
#     162     from pandas.io.sas.sas7bdat import SAS7BDATReader
#
# ...

# %%
nb_lines = df_raw.shape[0]
nb_columns = df_raw.shape[1]

print(f"lines number : {nb_lines}")
print(f"columns number : {nb_columns}")
